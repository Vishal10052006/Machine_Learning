# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Scatterplot (numerical - numerical)

# %%
dataset = pd.read_csv('dataset.csv')
dataset.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
itc = pd.read_csv('ITC Historical Data.csv')
itc
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     30-04-2019  301.35  304.55  307.55  299.50   11.16M   -1.05%
# 1     26-04-2019  304.55  304.60  306.40  302.55    4.65M    0.13%
# 2     25-04-2019  304.15  307.25  309.80  302.00   23.24M   -0.75%
# 3     24-04-2019  306.45  303.40  307.20  298.50   11.45M    1.01%
# 4     23-04-2019  303.40  302.15  304.80  301.55    7.50M    0.53%
# ...          ...     ...     ...     ...     ...      ...      ...
# 4995  08-04-1999   20.97   20.95   21.18   20.70   47.12M    0.38%
# 4996  07-04-1999   20.89   20.88   21.52   20.65  125.88M   -0.52%
# 4997  06-04-1999   21.00   19.49   21.00   19.36  142.79M    7.97%
# 4998  05-04-1999   19.45   20.11   20.33   19.25   67.43M   -6.89%
# 4999  01-04-1999   20.89   21.38   21.42   20.89   47.54M   -1.83%
#
# [5000 rows x 7 columns]

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.scatterplot(y = train['PassengerId'], x = train['Fare'], hue = train['Survived'], style = train['Pclass'])
# Out:
# <Axes: xlabel='Fare', ylabel='PassengerId'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=train['Pclass'], y=train['Fare'], hue= train['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(x=train['Sex'], y=train['Age'], hue=train['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.distplot(train[train['Survived']==0]['Age'], hist=False)
sns.distplot(train[train['Survived']==1]['Age'], hist=False)
# Out:
# C:\Users\vasis\AppData\Local\Temp\ipykernel_16124\1920866008.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train[train['Survived']==0]['Age'], hist=False)
# C:\Users\vasis\AppData\Local\Temp\ipykernel_16124\1920866008.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(pd.crosstab(train['Pclass'], train['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# train.groupby('Pclass').mean()['Survived']*100

# %%
# Convert Survived column to numeric type first, then calculate mean
train['Survived'] = train['Survived'].astype(float)  # Convert to numeric type

train.groupby('Sex')['Survived'].mean()*100 # Calculate percentage

# Alternative approach if the above doesn't work
# result = train.groupby('Pclass')['Survived'].agg(lambda x: x.mean() * 100)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.pairplot(train)

# %%
sns.lineplot(x=train['Age'], y=train['PassengerId'])
# Out:
# <Axes: xlabel='Age', ylabel='PassengerId'>

# %%
itc.head()
# Out:
#          Date   Price    Open    High     Low    Vol. Change %
# 0  30-04-2019  301.35  304.55  307.55  299.50  11.16M   -1.05%
# 1  26-04-2019  304.55  304.60  306.40  302.55   4.65M    0.13%
# 2  25-04-2019  304.15  307.25  309.80  302.00  23.24M   -0.75%
# 3  24-04-2019  306.45  303.40  307.20  298.50  11.45M    1.01%
# 4  23-04-2019  303.40  302.15  304.80  301.55   7.50M    0.53%

# %%
sns.pairplot(itc)

# %%
sns.lineplot(x=itc['Change %'], y=itc['Vol.'])
# Out:
# <Axes: xlabel='Change %', ylabel='Vol.'>
