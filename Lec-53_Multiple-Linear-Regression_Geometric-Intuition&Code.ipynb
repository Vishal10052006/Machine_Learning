# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.930352 -0.047997 -24.150911
# 1 -1.293486  1.806056  80.992035
# 2  1.417994  0.151051  96.229608
# 3  0.634399  0.064195  13.118764
# 4  0.569775  0.880201  98.710159

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("R2 score", r2_score(y_test, y_pred))
# Out:
# MAE 66.8815409039125
# MSE 6676.691420070869
# R2 score 0.6388150444669184

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10,10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 5
#       2 y = np.linspace(-5, 5, 10)
#       3 xGrid, yGrid = np.meshgrid(y, x)
# ----> 5 z_final = lr.predict(final).reshape(10,10)
#       7 z = z_final
#       9 final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
#
# NameError: name 'final' is not defined

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# Assuming df is already defined with your data
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

# Create grid values for the surface
# Replace these with appropriate values for your specific use case
x_range = np.linspace(min(df['feature1']), max(df['feature1']), 20)
y_range = np.linspace(min(df['feature2']), max(df['feature2']), 20)
x, y = np.meshgrid(x_range, y_range)

# Create z values for the surface (example: simple function)
# Replace this with your actual surface function or model prediction
z = x**2 + y**2  # Example function, modify as needed

fig.add_trace(go.Surface(x=x, y=y, z=z))

fig.show()

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %%
lr.coef_
# Out:
# array([33.92607384, 90.48691014])

# %%
lr.intercept_
# Out:
# 2.367351396410684
